# %% [markdown]
# <a href="https://colab.research.google.com/github/cesarpaico1511/Asistente_MVCS/blob/main/Sesion5_CesarPaico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Sección 1**

# %% [markdown]
# # Sección 2
